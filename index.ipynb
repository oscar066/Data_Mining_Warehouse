# %% [markdown]
# ### Data Warehousing and data mining task

# %%
# importing the necessary libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading the dataset

# %%
# Loading the dataset into a pandas dataframe, skipping problematic rows on_bad_lines='skip',
data = pd.read_csv("sales_data_cleaned.csv", encoding = 'unicode_escape')
data.head(10)
# Out:
#    ORDERNUMBER   QUANTITYORDERED   PRICEEACH   ORDERLINENUMBER   SALES     \
# 0        10107                30       95.70                 2    2871.00
# 1        10121                34       81.35                 5    2765.90
# 2        10134                41       94.74                 2    3884.34
# 3        10145                45       83.26                 6    3746.70
# 4        10159                49      100.00                14    5205.27
# 5        10168                36       96.66                 1    3479.76
# 6        10180                29       86.13                 9    2497.77
# 7        10188                48      100.00                 1    5512.32
# 8        10201                22       98.57                 2    2168.54
# 9        10211                41      100.00                14    4708.44
#
#     ORDERDATE         STATUS       QTR_ID   MONTH_ID   YEAR_ID  ...  \
# 0   2/24/2003 0:00    Shipped           1          2      2003  ...
# 1   5/7/2003 0:00     Shipped           2          5      2003  ...
# 2   7/1/2003 0:00     Shipped           3          7      2003  ...
# 3   8/25/2003 0:00    Shipped           3          8      2003  ...
# 4   10/10/2003 0:00   Shipped           4         10      2003  ...
# 5   10/28/2003 0:00   Shipped           4         10      2003  ...
# 6   11/11/2003 0:00   Shipped           4         11      2003  ...
# 7   11/18/2003 0:00   Shipped           4         11      2003  ...
# 8   12/1/2003 0:00    Shipped           4         12      2003  ...
# 9   1/15/2004 0:00    Shipped           1          1      2004  ...
#
#     ADDRESSLINE1                                 ADDRESSLINE2  \
# 0   897 Long Airport Avenue
# 1   59 rue de l'Abbaye
# 2   27 rue du Colonel Pierre Avia
# 3   78934 Hillside Dr.
# 4   7734 Strong St.
# 5   9408 Furth Circle
# 6    "184 chausse de Tournai"
# 7    "Drammen 121 PR 744 Sentrum"
# 8   5557 North Pendale Street
# 9    "25 rue Lauriston"
#
#     CITY             STATE           POSTALCODE   COUNTRY       TERRITORY  \
# 0   NYC              NY              10022        USA           NA
# 1   Reims                            51100        France        EMEA
# 2   Paris                            75508        France        EMEA
# 3   Pasadena         CA              90003        USA           NA
# 4   San Francisco    CA                           USA           NA
# 5   Burlingame       CA              94217        USA           NA
# 6   Lille                            59000        France        EMEA
# 7   Bergen                           N 5804       Norway        EMEA
# 8   San Francisco    CA                           USA           NA
# 9   Paris                            75016        France        EMEA
#
#     CONTACTLASTNAME   CONTACTFIRSTNAME  DEALSIZE
# 0   Yu                Kwai                 Small
# 1   Henriot           Paul                 Small
# 2   Da Cunha          Daniel              Medium
# 3   Young             Julie               Medium
# 4   Brown             Julie               Medium
# 5   Hirano            Juri                Medium
# 6   Rance             Martine              Small
# 7   Oeztan            Veysel              Medium
# 8   Murphy            Julie                Small
# 9   Perrier           Dominique           Medium
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Data Understanding

# %%
# getting the columns of the dataset
data.columns
# Out:
# Index(['ORDERNUMBER', ' QUANTITYORDERED', ' PRICEEACH', ' ORDERLINENUMBER',
#        ' SALES   ', ' ORDERDATE      ', ' STATUS    ', ' QTR_ID', ' MONTH_ID',
#        ' YEAR_ID', ' PRODUCTLINE     ', ' MSRP', ' PRODUCTCODE',
#        ' CUSTOMERNAME                        ', ' PHONE            ',
#        ' ADDRESSLINE1                              ', ' ADDRESSLINE2',
#        ' CITY          ', ' STATE        ', ' POSTALCODE', ' COUNTRY    ',
#        ' TERRITORY', ' CONTACTLASTNAME', ' CONTACTFIRSTNAME', ' DEALSIZE'],
#       dtype='object')

# %%
# random sampling of the dataset
data.sample(10)
# Out:
#       ORDERNUMBER   QUANTITYORDERED   PRICEEACH   ORDERLINENUMBER   SALES     \
# 1722        10175                37       31.12                 2    1151.44
# 187         10117                33      100.00                 9    6034.38
# 714         10259                34       99.41                 7    3379.94
# 491         10304                37       95.55                13    3535.35
# 1448        10220                26       56.07                 8    1457.82
# 965         10150                26      100.00                10    2804.36
# 2091        10324                33      100.00                 3    6267.69
# 611         10239                46       73.92                 4    3400.32
# 2507        10401                11      100.00                 8    1135.31
# 2594        10177                32       76.62                 1    2451.84
#
#        ORDERDATE         STATUS       QTR_ID   MONTH_ID   YEAR_ID  ...  \
# 1722   11/6/2003 0:00    Shipped           4         11      2003  ...
# 187    4/16/2003 0:00    Shipped           2          4      2003  ...
# 714    6/15/2004 0:00    Shipped           2          6      2004  ...
# 491    10/11/2004 0:00   Shipped           4         10      2004  ...
# 1448   2/12/2004 0:00    Shipped           1          2      2004  ...
# 965    9/19/2003 0:00    Shipped           3          9      2003  ...
# 2091   11/5/2004 0:00    Shipped           4         11      2004  ...
# 611    4/12/2004 0:00    Shipped           2          4      2004  ...
# 2507   4/3/2005 0:00     On Hold           2          4      2005  ...
# 2594   11/7/2003 0:00    Shipped           4         11      2003  ...
#
#        ADDRESSLINE1                                 ADDRESSLINE2  \
# 1722   35 King George
# 187     "Bronz Sok. Bronz Apt. 3/6 Tesvikiye"
# 714    Village Close - 106 Linden Road Sandown      2nd Floor
# 491     "67 avenue de l'Europe"
# 1448   25 Maiden Lane                               Floor No. 4
# 965     "Bronz Sok. Bronz Apt. 3/6 Tesvikiye"
# 2091   2678 Kingston Rd.                            Suite 101
# 611    Torikatu 38
# 2507   7476 Moss Rd.
# 2594    "Merchants House 27-30 Merchant's Quay"
#
#        CITY             STATE           POSTALCODE   COUNTRY       TERRITORY  \
# 1722   London                           WX3 6FW      UK            EMEA
# 187    Singapore                        79903        Singapore     Japan
# 714    Singapore                        69045        Singapore     APAC
# 491    Versailles                       78000        France        EMEA
# 1448   Dublin                           2            Ireland       EMEA
# 965    Singapore                        79903        Singapore     Japan
# 2091   NYC              NY              10022        USA           NA
# 611    Oulu                             90110        Finland       EMEA
# 2507   Newark           NJ              94019        USA           NA
# 2594   Madrid                           28023        Spain         EMEA
#
#        CONTACTLASTNAME   CONTACTFIRSTNAME  DEALSIZE
# 1722   Brown             Ann                  Small
# 187    Natividad         Eric                Medium
# 714    Victorino         Wendy               Medium
# 491    Tonini            Daniel              Medium
# 1448   Cassidy           Dean                 Small
# 965    Natividad         Eric                 Small
# 2091   Frick             Michael             Medium
# 611    Koskitalo         Pirkko              Medium
# 2507   Brown             William              Small
# 2594   Fernandez         Jesus                Small
#
# [10 rows x 25 columns]

# %%
# preview the tail of the dataset
data.tail(10)
# Out:
#       ORDERNUMBER   QUANTITYORDERED   PRICEEACH   ORDERLINENUMBER   SALES     \
# 2813        10293                32       60.06                 1    1921.92
# 2814        10306                35       59.51                 6    2082.85
# 2815        10315                40       55.69                 5    2227.60
# 2816        10327                37       86.74                 4    3209.38
# 2817        10337                42       97.16                 5    4080.72
# 2818        10350                20      100.00                15    2244.40
# 2819        10373                29      100.00                 1    3978.51
# 2820        10386                43      100.00                 4    5417.57
# 2821        10397                34       62.24                 1    2116.16
# 2822        10414                47       65.52                 9    3079.44
#
#        ORDERDATE         STATUS       QTR_ID   MONTH_ID   YEAR_ID  ...  \
# 2813   9/9/2004 0:00     Shipped           3          9      2004  ...
# 2814   10/14/2004 0:00   Shipped           4         10      2004  ...
# 2815   10/29/2004 0:00   Shipped           4         10      2004  ...
# 2816   11/10/2004 0:00   Resolved          4         11      2004  ...
# 2817   11/21/2004 0:00   Shipped           4         11      2004  ...
# 2818   12/2/2004 0:00    Shipped           4         12      2004  ...
# 2819   1/31/2005 0:00    Shipped           1          1      2005  ...
# 2820   3/1/2005 0:00     Resolved          1          3      2005  ...
# 2821   3/28/2005 0:00    Shipped           1          3      2005  ...
# 2822   5/6/2005 0:00     On Hold           2          5      2005  ...
#
#        ADDRESSLINE1                                 ADDRESSLINE2  \
# 2813   Via Monte Bianco 34
# 2814   Fauntleroy Circus
# 2815    "67 rue des Cinquante Otages"
# 2816   Vinb'ltet 34
# 2817   5905 Pompton St.                             Suite 750
# 2818    "C/ Moralzarzal 86"
# 2819   Torikatu 38
# 2820    "C/ Moralzarzal 86"
# 2821   1 rue Alsace-Lorraine
# 2822   8616 Spinnaker Dr.
#
#        CITY             STATE           POSTALCODE   COUNTRY       TERRITORY  \
# 2813   Torino                           10100        Italy         EMEA
# 2814   Manchester                       EC2 5NT      UK            EMEA
# 2815   Nantes                           44000        France        EMEA
# 2816   Kobenhavn                        1734         Denmark       EMEA
# 2817   NYC              NY              10022        USA           NA
# 2818   Madrid                           28034        Spain         EMEA
# 2819   Oulu                             90110        Finland       EMEA
# 2820   Madrid                           28034        Spain         EMEA
# 2821   Toulouse                         31000        France        EMEA
# 2822   Boston           MA              51003        USA           NA
#
#        CONTACTLASTNAME   CONTACTFIRSTNAME  DEALSIZE
# 2813   Accorti           Paolo                Small
# 2814   Ashworth          Victoria             Small
# 2815   Labrune           Janine               Small
# 2816   Petersen          Jytte               Medium
# 2817   Hernandez         Maria               Medium
# 2818   Freyre            Diego                Small
# 2819   Koskitalo         Pirkko              Medium
# 2820   Freyre            Diego               Medium
# 2821   Roulet            Annette              Small
# 2822   Yoshido           Juri                Medium
#
# [10 rows x 25 columns]

# %%
# getting more information on the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   ORDERNUMBER                                  2823 non-null   int64
#  1    QUANTITYORDERED                             2823 non-null   int64
#  2    PRICEEACH                                   2823 non-null   float64
#  3    ORDERLINENUMBER                             2823 non-null   int64
#  4    SALES                                       2823 non-null   float64
#  5    ORDERDATE                                   2823 non-null   object
#  6    STATUS                                      2823 non-null   object
#  7    QTR_ID                                      2823 non-null   int64
#  8    MONTH_ID                                    2823 non-null   int64
#  9    YEAR_ID                                     2823 non-null   int64
#  10   PRODUCTLINE                                 2823 non-null   object
#  11   MSRP                                        2823 non-null   int64
#  12   PRODUCTCODE                                 2823 non-null   object
#  13   CUSTOMERNAME                                2823 non-null   object
#  14   PHONE                                       2823 non-null   object
#  15   ADDRESSLINE1                                2823 non-null   object
#  16   ADDRESSLINE2                                2823 non-null   object
#  17   CITY                                        2823 non-null   object
#  18   STATE                                       2823 non-null   object
#  19   POSTALCODE                                  2823 non-null   object
#  20   COUNTRY                                     2823 non-null   object
#  21   TERRITORY                                   2823 non-null   object
#  22   CONTACTLASTNAME                             2823 non-null   object
#  23   CONTACTFIRSTNAME                            2823 non-null   object
#  24   DEALSIZE                                    2823 non-null   object
# dtypes: float64(2), int64(7), object(16)
# memory usage: 551.5+ KB

# %% [markdown]
# ### Data Cleaning

# %%
## check for missing values
data.isna().sum()
# Out:
# ORDERNUMBER                                    0
#  QUANTITYORDERED                               0
#  PRICEEACH                                     0
#  ORDERLINENUMBER                               0
#  SALES                                         0
#  ORDERDATE                                     0
#  STATUS                                        0
#  QTR_ID                                        0
#  MONTH_ID                                      0
#  YEAR_ID                                       0
#  PRODUCTLINE                                   0
#  MSRP                                          0
#  PRODUCTCODE                                   0
#  CUSTOMERNAME                                  0
#  PHONE                                         0
#  ADDRESSLINE1                                  0
#  ADDRESSLINE2                                  0
#  CITY                                          0
#  STATE                                         0
#  POSTALCODE                                    0
#  COUNTRY                                       0
#  TERRITORY                                     0
#  CONTACTLASTNAME                               0
#  CONTACTFIRSTNAME                              0
#  DEALSIZE                                      0
# dtype: int64

# %%
data.columns.str.strip()
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
# checking for consistency
## checking for duplicated values 

data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Exercise 1 Data splitting

# %% [markdown]
# #### 1. Create Orders Dataset

# %%
# Select columns for orders, including foreign keys for product and customer.

# Strip leading spaces from column names
data.columns = data.columns.str.strip()

orders_cols = [
    'ORDERNUMBER', 'ORDERDATE', 'SALES', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
    'ORDERLINENUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'PRODUCTCODE', 'CUSTOMERNAME'
]
orders_df = data[orders_cols]

orders_df.head(10)

# Save orders to CSV
orders_df.to_csv('Exercise1_data/orders.csv', index=False)

# %%
orders_df.shape
# Out:
# (2823, 12)

# %%
orders_df.head(10)
# Out:
#    ORDERNUMBER         ORDERDATE    SALES       STATUS  QTR_ID  MONTH_ID  \
# 0        10107   2/24/2003 0:00   2871.00   Shipped          1         2
# 1        10121   5/7/2003 0:00    2765.90   Shipped          2         5
# 2        10134   7/1/2003 0:00    3884.34   Shipped          3         7
# 3        10145   8/25/2003 0:00   3746.70   Shipped          3         8
# 4        10159   10/10/2003 0:00  5205.27   Shipped          4        10
# 5        10168   10/28/2003 0:00  3479.76   Shipped          4        10
# 6        10180   11/11/2003 0:00  2497.77   Shipped          4        11
# 7        10188   11/18/2003 0:00  5512.32   Shipped          4        11
# 8        10201   12/1/2003 0:00   2168.54   Shipped          4        12
# 9        10211   1/15/2004 0:00   4708.44   Shipped          1         1
#
#    YEAR_ID  ORDERLINENUMBER  QUANTITYORDERED  PRICEEACH   PRODUCTCODE  \
# 0     2003                2               30      95.70   S10_1678
# 1     2003                5               34      81.35   S10_1678
# 2     2003                2               41      94.74   S10_1678
# 3     2003                6               45      83.26   S10_1678
# 4     2003               14               49     100.00   S10_1678
# 5     2003                1               36      96.66   S10_1678
# 6     2003                9               29      86.13   S10_1678
# 7     2003                1               48     100.00   S10_1678
# 8     2003                2               22      98.57   S10_1678
# 9     2004               14               41     100.00   S10_1678
#
#                             CUSTOMERNAME
# 0   Land of Toys Inc.
# 1   Reims Collectables
# 2   Lyon Souveniers
# 3   Toys4GrownUps.com
# 4   Corporate Gift Ideas Co.
# 5   Technics Stores Inc.
# 6   Daedalus Designs Imports
# 7   Herkku Gifts
# 8   Mini Wheels Co.
# 9   Auto Canal Petit

# %%
orders_df.columns
# Out:
# Index(['ORDERNUMBER', 'ORDERDATE', 'SALES', 'STATUS', 'QTR_ID', 'MONTH_ID',
#        'YEAR_ID', 'ORDERLINENUMBER', 'QUANTITYORDERED', 'PRICEEACH',
#        'PRODUCTCODE', 'CUSTOMERNAME'],
#       dtype='object')

# %% [markdown]
# #### Splitting based on years

# %%
def split_orders_by_year(df: pd.DataFrame) -> dict:
    # Group the DataFrame by the 'YEAR_ID' column and create a dictionary of DataFrames.
    orders_by_year = {year: group.copy() for year, group in df.groupby('YEAR_ID')}
    return orders_by_year

# %%
# Splitting the orders DataFrame by year
orders_by_year = split_orders_by_year(orders_df)

# # Displaying the keys and corresponding DataFrames
# for year, df_year in orders_by_year.items():
#     print(f"Year: {year}")
#     print(df_year, "\n")

# %%
orders_by_year.keys()
# Out:
# dict_keys([2003, 2004, 2005])

# %%
from pathlib import Path

Exercise1_data1 = Path("Exercise1_data1")
Exercise1_data1.mkdir(exist_ok=True) 

# Save each year's DataFrame as a CSV file
for year, df_year in orders_by_year.items():
    filename = f"orders_{year}.csv"
    df_year.to_csv(Exercise1_data1 / filename, index=False)
    print(f"Saved {filename}")
# Out:
# Saved orders_2003.csv
# Saved orders_2004.csv
# Saved orders_2005.csv

# %% [markdown]
# ### 2. Create Customers Dataset

# %%
# Select customer columns. Drop duplicates if customers appear in multiple rows.

customers_cols = ['CUSTOMERNAME', 'PHONE', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME']

customers_df = data[customers_cols].drop_duplicates()

# Save customers to CSV
customers_df.to_csv('Exercise1_data/customers.csv', index=False)

# %%
customers_df.shape
# Out:
# (2823, 4)

# %%
customers_df.head(10)
# Out:
#                             CUSTOMERNAME               PHONE  \
# 0   Land of Toys Inc.                      2125557818
# 1   Reims Collectables                     26.47.1555
# 2   Lyon Souveniers                        +33 1 46 62 7555
# 3   Toys4GrownUps.com                      6265557265
# 4   Corporate Gift Ideas Co.               6505551386
# 5   Technics Stores Inc.                   6505556809
# 6   Daedalus Designs Imports               20.16.1555
# 7   Herkku Gifts                           +47 2267 3215
# 8   Mini Wheels Co.                        6505555787
# 9   Auto Canal Petit                       (1) 47.55.6555
#
#     CONTACTLASTNAME   CONTACTFIRSTNAME
# 0   Yu                Kwai
# 1   Henriot           Paul
# 2   Da Cunha          Daniel
# 3   Young             Julie
# 4   Brown             Julie
# 5   Hirano            Juri
# 6   Rance             Martine
# 7   Oeztan            Veysel
# 8   Murphy            Julie
# 9   Perrier           Dominique

# %% [markdown]
# ### 3. Create Products Dataset

# %%
# Select product-related columns. Drop duplicates to keep unique products.

products_cols = ['PRODUCTCODE', 'PRODUCTLINE', 'MSRP', 'DEALSIZE']
products_df = data[products_cols].drop_duplicates()

# Save products to CSV
products_df.to_csv('Exercise1_data/products.csv', index=False)

# %%
products_df.shape
# Out:
# (266, 4)

# %%
products_df.head(10)
# Out:
#      PRODUCTCODE        PRODUCTLINE  MSRP DEALSIZE
# 0    S10_1678      Motorcycles         95    Small
# 2    S10_1678      Motorcycles         95   Medium
# 20   S10_1678      Motorcycles         95    Large
# 26   S10_1949      Classic Cars       214   Medium
# 27   S10_1949      Classic Cars       214    Large
# 51   S10_1949      Classic Cars       214    Small
# 54   S10_2016      Motorcycles        118   Medium
# 55   S10_2016      Motorcycles        118    Small
# 80   S10_4698      Motorcycles        193   Medium
# 81   S10_4698      Motorcycles        193    Large

# %% [markdown]
# ### 4. Create Addresses Dataset

# %%
# Select address-related columns. Drop duplicates to keep unique addresses.

addresses_cols = ['ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY']

addresses_df = data[addresses_cols].drop_duplicates()

# Save addresses to CSV
addresses_df.to_csv('Exercise1_data/addresses.csv', index=False)

# %%
addresses_df.shape
# Out:
# (92, 7)

# %%
addresses_df.head(10)
# Out:
#                                   ADDRESSLINE1   ADDRESSLINE2  \
# 0   897 Long Airport Avenue
# 1   59 rue de l'Abbaye
# 2   27 rue du Colonel Pierre Avia
# 3   78934 Hillside Dr.
# 4   7734 Strong St.
# 5   9408 Furth Circle
# 6    "184 chausse de Tournai"
# 7    "Drammen 121 PR 744 Sentrum"
# 8   5557 North Pendale Street
# 9    "25 rue Lauriston"
#
#               CITY           STATE   POSTALCODE       COUNTRY   TERRITORY
# 0   NYC              NY              10022        USA           NA
# 1   Reims                            51100        France        EMEA
# 2   Paris                            75508        France        EMEA
# 3   Pasadena         CA              90003        USA           NA
# 4   San Francisco    CA                           USA           NA
# 5   Burlingame       CA              94217        USA           NA
# 6   Lille                            59000        France        EMEA
# 7   Bergen                           N 5804       Norway        EMEA
# 8   San Francisco    CA                           USA           NA
# 9   Paris                            75016        France        EMEA

# %% [markdown]
# ### Excercise 2 Data Splitting

# %%
data.columns.str.strip()
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %% [markdown]
# ### 1. Split for Fact Table: Orders

# %%
orders2_cols = [
    'ORDERNUMBER', 'ORDERDATE', 'SALES', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
    'ORDERLINENUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'PRODUCTCODE', 'CUSTOMERNAME'
]

orders2_df = data[orders2_cols]

orders2_df.to_csv('Exercise2_data/orders.csv', index=False)

# %%
orders2_df.shape
# Out:
# (2823, 12)

# %%
orders2_df.head(10)
# Out:
#    ORDERNUMBER         ORDERDATE    SALES       STATUS  QTR_ID  MONTH_ID  \
# 0        10107   2/24/2003 0:00   2871.00   Shipped          1         2
# 1        10121   5/7/2003 0:00    2765.90   Shipped          2         5
# 2        10134   7/1/2003 0:00    3884.34   Shipped          3         7
# 3        10145   8/25/2003 0:00   3746.70   Shipped          3         8
# 4        10159   10/10/2003 0:00  5205.27   Shipped          4        10
# 5        10168   10/28/2003 0:00  3479.76   Shipped          4        10
# 6        10180   11/11/2003 0:00  2497.77   Shipped          4        11
# 7        10188   11/18/2003 0:00  5512.32   Shipped          4        11
# 8        10201   12/1/2003 0:00   2168.54   Shipped          4        12
# 9        10211   1/15/2004 0:00   4708.44   Shipped          1         1
#
#    YEAR_ID  ORDERLINENUMBER  QUANTITYORDERED  PRICEEACH   PRODUCTCODE  \
# 0     2003                2               30      95.70   S10_1678
# 1     2003                5               34      81.35   S10_1678
# 2     2003                2               41      94.74   S10_1678
# 3     2003                6               45      83.26   S10_1678
# 4     2003               14               49     100.00   S10_1678
# 5     2003                1               36      96.66   S10_1678
# 6     2003                9               29      86.13   S10_1678
# 7     2003                1               48     100.00   S10_1678
# 8     2003                2               22      98.57   S10_1678
# 9     2004               14               41     100.00   S10_1678
#
#                             CUSTOMERNAME
# 0   Land of Toys Inc.
# 1   Reims Collectables
# 2   Lyon Souveniers
# 3   Toys4GrownUps.com
# 4   Corporate Gift Ideas Co.
# 5   Technics Stores Inc.
# 6   Daedalus Designs Imports
# 7   Herkku Gifts
# 8   Mini Wheels Co.
# 9   Auto Canal Petit

# %% [markdown]
# ### 2. Split for Customers Dimension

# %%
customers2_cols = ['CUSTOMERNAME', 'PHONE', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME']

customers2_df = data[customers2_cols].drop_duplicates()

customers2_df.to_csv('Exercise2_data/customers.csv', index=False)

# %%
customers2_df.shape
# Out:
# (92, 4)

# %%
customers2_df.sample(10)
# Out:
#                               CUSTOMERNAME               PHONE  \
# 37    Cambridge Collectables Co.             6175555555
# 171    "Vida Sport Ltd"                      0897-034555
# 8     Mini Wheels Co.                        6505555787
# 106   Danish Wholesale Imports               31 12 3555
# 121   Gifts4AllAges.com                      6175559555
# 128    "Oulu Toy Supplies Inc."              981-443655
# 464    "Norway Gifts By Mail Co."            +47 2212 1555
# 937   Auto-Moto Classics Inc.                6175558428
# 34     "Saveley & Henriot Co."               78.32.5555
# 32     "Australian Gift Network Co"          61-7-3844-6555
#
#       CONTACTLASTNAME   CONTACTFIRSTNAME
# 37    Tseng             Kyung
# 171   Holz              Michael
# 8     Murphy            Julie
# 106   Petersen          Jytte
# 121   Yoshido           Juri
# 128   Koskitalo         Pirkko
# 464   Klaeboe           Jan
# 937   Taylor            Leslie
# 34    Saveley           Mary
# 32    Calaghan          Tony

# %% [markdown]
# ### 3. Split for Products Dimension

# %%
products2_cols = ['PRODUCTCODE', 'PRODUCTLINE', 'MSRP', 'DEALSIZE']

products2_df = data[products2_cols].drop_duplicates()

products2_df.to_csv('Exercise2_data/products.csv', index=False)

# %%
products2_df.shape
# Out:
# (266, 4)

# %%
products2_df.sample(10)
# Out:
#        PRODUCTCODE        PRODUCTLINE  MSRP DEALSIZE
# 1986   S24_3856      Classic Cars       140    Large
# 1771   S24_2887      Classic Cars       117    Small
# 268    S12_3148      Classic Cars       151    Large
# 1190   S18_3782      Motorcycles         62    Small
# 1269   S18_4409      Vintage Cars        92   Medium
# 1845   S24_3191      Classic Cars        85    Small
# 1633   S24_2022      Vintage Cars        44   Medium
# 2371   S50_1341      Vintage Cars        43   Medium
# 600    S18_1889      Classic Cars        77   Medium
# 2149   S32_1268      Trucks and Buses    96    Small

# %% [markdown]
# ### 4. Split for Addresses Dimension

# %%
# --- Split for Addresses Dimension ---
addresses2_cols = ['ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY']

addresses2_df = data[addresses2_cols].drop_duplicates()

addresses2_df.to_csv('Exercise2_data/addresses.csv', index=False)

# %%
addresses2_df.shape
# Out:
# (92, 7)

# %%
addresses2_df.sample(10)
# Out:
#                                     ADDRESSLINE1   ADDRESSLINE2  \
# 142   6251 Ingle Ln.
# 44    5677 Strong St.
# 70     "54 rue Royale"
# 13    25593 South Bay Ln.
# 196   25 Maiden Lane                               Floor No. 4
# 116   361 Furth Circle
# 481   Via Ludovico il Moro 22
# 7      "Drammen 121 PR 744 Sentrum"
# 462   8489 Strong St.
# 131   3086 Ingle Ln.
#
#                 CITY           STATE   POSTALCODE       COUNTRY   TERRITORY
# 142   Boston           MA              51003        USA           NA
# 44    San Rafael       CA              97562        USA           NA
# 70    Nantes                           44000        France        EMEA
# 13    Bridgewater      CT              97562        USA           NA
# 196   Dublin                           2            Ireland       EMEA
# 116   San Diego        CA              91217        USA           NA
# 481   Bergamo                          24100        Italy         EMEA
# 7     Bergen                           N 5804       Norway        EMEA
# 462   Las Vegas        NV              83030        USA           NA
# 131   San Jose         CA              94217        USA           NA

# %%
## more analysis on the dataset
